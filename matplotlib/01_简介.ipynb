# %% [markdown]
# # 简介

# %% [markdown]
# Matplotlib 是 Python 的绘图库，它能让使用者很轻松地将数据图形化，并且提供多样化的输出格式。
#
# Matplotlib 可以用来绘制各种静态，动态，交互式的图表。
#
# Matplotlib 是一个非常强大的 Python 画图工具，我们可以使用该工具将很多数据通过图表的形式更直观的呈现出来。
#
# Matplotlib 可以绘制线图、散点图、等高线图、条形图、柱状图、3D 图形、甚至是图形动画等等。

# %% [markdown]
# ## Matplotlib 应用

# %% [markdown]
# Matplotlib 通常与 NumPy 和 SciPy（Scientific Python）一起使用， 这种组合广泛用于替代 MatLab，是一个强大的科学计算环境，有助于我们通过 Python 学习数据科学或者机器学习。
#
# SciPy 是一个开源的 Python 算法库和数学工具包。
#
# SciPy 包含的模块有最优化、线性代数、积分、插值、特殊函数、快速傅里叶变换、信号处理和图像处理、常微分方程求解和其他科学与工程中常用的计算。

# %% [markdown]
# ## 安装

# %% [markdown]
# Matplotlib 是一个强大的 Python 绘图库，用于创建各种类型的静态、动态和交互式图表。

# %%
conda install matplotlib
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\anaconda\envs\dl
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       h2bbff1b_8          19 KB
#     brotli-bin-1.0.9           |       h2bbff1b_8          29 KB
#     bzip2-1.0.8                |       h2bbff1b_6          90 KB
#     contourpy-1.0.5            |   py38h59b6b97_0         159 KB
#     fonttools-4.51.0           |   py38h2bbff1b_0         2.0 MB
#     importlib_resources-6.4.0  |   py38haa95532_0          61 KB
#     kiwisolver-1.4.4           |   py38hd77b12b_0          60 KB
#     krb5-1.19.4                |       h5b6d351_0         786 KB
#     libbrotlicommon-1.0.9      |       h2bbff1b_8          79 KB
#     libbrotlidec-1.0.9         |       h2bbff1b_8          39 KB
#     libbrotlienc-1.0.9         |       h2bbff1b_8         261 KB
#     libclang-14.0.6            |default_hb5a9fac_1         154 KB
#     libclang13-14.0.6          |default_h8e68704_1        22.5 MB
#     libiconv-1.16              |       h2bbff1b_3         685 KB
#     matplotlib-3.7.2           |   py38haa95532_0           9 KB
#     matplotlib-base-3.7.2      |   py38h4ed8f06_0         6.6 MB
#     ply-3.11                   |           py38_0          81 KB
#     pyparsing-3.0.9            |   py38haa95532_0         152 KB
#     pyqt-5.15.10               |   py38hd77b12b_0         4.1 MB
#     pyqt5-sip-12.13.0          |   py38h2bbff1b_0          75 KB
#     qt-main-5.15.2             |       he8e5bd7_8        59.4 MB
#     sip-6.7.12                 |   py38hd77b12b_0         518 KB
#     tomli-2.0.1                |   py38haa95532_0          25 KB
#     unicodedata2-15.1.0        |   py38h2bbff1b_0         525 KB
#     ------------------------------------------------------------
#                                            Total:        98.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             pkgs/main/win-64::brotli-1.0.9-h2bbff1b_8 None
#   brotli-bin         pkgs/main/win-64::brotli-bin-1.0.9-h2bbff1b_8 None
#   bzip2              pkgs/main/win-64::bzip2-1.0.8-h2bbff1b_6 None
#   contourpy          pkgs/main/win-64::contourpy-1.0.5-py38h59b6b97_0 None
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0 None
#   fonttools          pkgs/main/win-64::fonttools-4.51.0-py38h2bbff1b_0 None
#   glib               pkgs/main/win-64::glib-2.78.4-hd77b12b_0 None
#   glib-tools         pkgs/main/win-64::glib-tools-2.78.4-hd77b12b_0 None
#   gst-plugins-base   pkgs/main/win-64::gst-plugins-base-1.18.5-h9e645db_0 None
#   gstreamer          pkgs/main/win-64::gstreamer-1.18.5-hd78058f_0 None
#   importlib_resourc~ pkgs/main/win-64::importlib_resources-6.4.0-py38haa95532_0 None
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.4.4-py38hd77b12b_0 None
#   krb5               pkgs/main/win-64::krb5-1.19.4-h5b6d351_0 None
#   libbrotlicommon    pkgs/main/win-64::libbrotlicommon-1.0.9-h2bbff1b_8 None
#   libbrotlidec       pkgs/main/win-64::libbrotlidec-1.0.9-h2bbff1b_8 None
#   libbrotlienc       pkgs/main/win-64::libbrotlienc-1.0.9-h2bbff1b_8 None
#   libclang           pkgs/main/win-64::libclang-14.0.6-default_hb5a9fac_1 None
#   libclang13         pkgs/main/win-64::libclang13-14.0.6-default_h8e68704_1 None
#   libglib            pkgs/main/win-64::libglib-2.78.4-ha17d25a_0 None
#   libiconv           pkgs/main/win-64::libiconv-1.16-h2bbff1b_3 None
#   libogg             pkgs/main/win-64::libogg-1.3.5-h2bbff1b_1 None
#   libvorbis          pkgs/main/win-64::libvorbis-1.3.7-he774522_0 None
#   matplotlib         pkgs/main/win-64::matplotlib-3.7.2-py38haa95532_0 None
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.7.2-py38h4ed8f06_0 None
#   pcre2              pkgs/main/win-64::pcre2-10.42-h0ff8eda_1 None
#   ply                pkgs/main/win-64::ply-3.11-py38_0 None
#   pyparsing          pkgs/main/win-64::pyparsing-3.0.9-py38haa95532_0 None
#   pyqt               pkgs/main/win-64::pyqt-5.15.10-py38hd77b12b_0 None
#   pyqt5-sip          pkgs/main/win-64::pyqt5-sip-12.13.0-py38h2bbff1b_0 None
#   qt-main            pkgs/main/win-64::qt-main-5.15.2-he8e5bd7_8 None
#   sip                pkgs/main/win-64::sip-6.7.12-py38hd77b12b_0 None
#   tomli              pkgs/main/win-64::tomli-2.0.1-py38haa95532_0 None
#   unicodedata2       pkgs/main/win-64::unicodedata2-15.1.0-py38h2bbff1b_0 None
#
#
#
# Downloading and Extracting Packages
#
# contourpy-1.0.5      | 159 KB    |            |   0%
# contourpy-1.0.5      | 159 KB    | #          |  10%
# contourpy-1.0.5      | 159 KB    | #####      |  50%
# contourpy-1.0.5      | 159 KB    | ########## | 100%
# contourpy-1.0.5      | 159 KB    | ########## | 100%
#
# unicodedata2-15.1.0  | 525 KB    |            |   0%
# unicodedata2-15.1.0  | 525 KB    | 3          |   3%
# unicodedata2-15.1.0  | 525 KB    | ##1        |  21%
# unicodedata2-15.1.0  | 525 KB    | ########2  |  82%
# unicodedata2-15.1.0  | 525 KB    | ########## | 100%
#
# libbrotlidec-1.0.9   | 39 KB     |            |   0%
# libbrotlidec-1.0.9   | 39 KB     | ####       |  41%
# libbrotlidec-1.0.9   | 39 KB     | ########## | 100%
# libbrotlidec-1.0.9   | 39 KB     | ########## | 100%
#
# brotli-bin-1.0.9     | 29 KB     |            |   0%
# brotli-bin-1.0.9     | 29 KB     | #####5     |  56%
# brotli-bin-1.0.9     | 29 KB     | ########## | 100%
#
# libclang13-14.0.6    | 22.5 MB   |            |   0%
# libclang13-14.0.6    | 22.5 MB   |            |   0%
# libclang13-14.0.6    | 22.5 MB   | 2          |   3%
# libclang13-14.0.6    | 22.5 MB   | 5          |   5%
# libclang13-14.0.6    | 22.5 MB   | #1         |  11%
# libclang13-14.0.6    | 22.5 MB   | #4         |  14%
# libclang13-14.0.6    | 22.5 MB   | ##2        |  23%
# libclang13-14.0.6    | 22.5 MB   | ###        |  30%
# libclang13-14.0.6    | 22.5 MB   | ###5       |  36%
# libclang13-14.0.6    | 22.5 MB   | ####       |  41%
# libclang13-14.0.6    | 22.5 MB   | ####5      |  45%
# libclang13-14.0.6    | 22.5 MB   | ####9      |  50%
# libclang13-14.0.6    | 22.5 MB   | #####3     |  54%
# libclang13-14.0.6    | 22.5 MB   | #####7     |  57%
# libclang13-14.0.6    | 22.5 MB   | #####9     |  60%
# libclang13-14.0.6    | 22.5 MB   | ######2    |  62%
# libclang13-14.0.6    | 22.5 MB   | ######5    |  66%
# libclang13-14.0.6    | 22.5 MB   | ######8    |  69%
# libclang13-14.0.6    | 22.5 MB   | #######1   |  72%
# libclang13-14.0.6    | 22.5 MB   | #######3   |  74%
# libclang13-14.0.6    | 22.5 MB   | #######6   |  76%
# libclang13-14.0.6    | 22.5 MB   | #######8   |  78%
# libclang13-14.0.6    | 22.5 MB   | ########   |  80%
# libclang13-14.0.6    | 22.5 MB   | ########2  |  82%
# libclang13-14.0.6    | 22.5 MB   | ########7  |  88%
# libclang13-14.0.6    | 22.5 MB   | #########  |  91%
# libclang13-14.0.6    | 22.5 MB   | #########3 |  93%
# libclang13-14.0.6    | 22.5 MB   | #########5 |  95%
# libclang13-14.0.6    | 22.5 MB   | #########6 |  97%
# libclang13-14.0.6    | 22.5 MB   | #########8 |  99%
# libclang13-14.0.6    | 22.5 MB   | ########## | 100%
#
# ply-3.11             | 81 KB     |            |   0%
# ply-3.11             | 81 KB     | #9         |  20%
# ply-3.11             | 81 KB     | ########## | 100%
# ply-3.11             | 81 KB     | ########## | 100%
#
# libbrotlienc-1.0.9   | 261 KB    |            |   0%
# libbrotlienc-1.0.9   | 261 KB    | 6          |   6%
# libbrotlienc-1.0.9   | 261 KB    | ########## | 100%
# libbrotlienc-1.0.9   | 261 KB    | ########## | 100%
#
# pyparsing-3.0.9      | 152 KB    |            |   0%
# pyparsing-3.0.9      | 152 KB    | #          |  11%
# pyparsing-3.0.9      | 152 KB    | ########## | 100%
# pyparsing-3.0.9      | 152 KB    | ########## | 100%
#
# bzip2-1.0.8          | 90 KB     |            |   0%
# bzip2-1.0.8          | 90 KB     | #7         |  18%
# bzip2-1.0.8          | 90 KB     | ########## | 100%
# bzip2-1.0.8          | 90 KB     | ########## | 100%
#
# libclang-14.0.6      | 154 KB    |            |   0%
# libclang-14.0.6      | 154 KB    | #          |  10%
# libclang-14.0.6      | 154 KB    | ########## | 100%
# libclang-14.0.6      | 154 KB    | ########## | 100%
#
# libiconv-1.16        | 685 KB    |            |   0%
# libiconv-1.16        | 685 KB    | 2          |   2%
# libiconv-1.16        | 685 KB    | ########## | 100%
# libiconv-1.16        | 685 KB    | ########## | 100%
#
# tomli-2.0.1          | 25 KB     |            |   0%
# tomli-2.0.1          | 25 KB     | ######4    |  64%
# tomli-2.0.1          | 25 KB     | ########## | 100%
#
# pyqt5-sip-12.13.0    | 75 KB     |            |   0%
# pyqt5-sip-12.13.0    | 75 KB     | ##1        |  21%
# pyqt5-sip-12.13.0    | 75 KB     | ########## | 100%
# pyqt5-sip-12.13.0    | 75 KB     | ########## | 100%
#
# kiwisolver-1.4.4     | 60 KB     |            |   0%
# kiwisolver-1.4.4     | 60 KB     | ##6        |  27%
# kiwisolver-1.4.4     | 60 KB     | ########## | 100%
# kiwisolver-1.4.4     | 60 KB     | ########## | 100%
#
# krb5-1.19.4          | 786 KB    |            |   0%
# krb5-1.19.4          | 786 KB    | 2          |   2%
# krb5-1.19.4          | 786 KB    | ####6      |  47%
# krb5-1.19.4          | 786 KB    | ########9  |  90%
# krb5-1.19.4          | 786 KB    | ########## | 100%
#
# brotli-1.0.9         | 19 KB     |            |   0%
# brotli-1.0.9         | 19 KB     | ########3  |  83%
# brotli-1.0.9         | 19 KB     | ########## | 100%
#
# sip-6.7.12           | 518 KB    |            |   0%
# sip-6.7.12           | 518 KB    | 3          |   3%
# sip-6.7.12           | 518 KB    | ########## | 100%
# sip-6.7.12           | 518 KB    | ########## | 100%
#
# libbrotlicommon-1.0. | 79 KB     |            |   0%
# libbrotlicommon-1.0. | 79 KB     | ##         |  20%
# libbrotlicommon-1.0. | 79 KB     | ########## | 100%
# libbrotlicommon-1.0. | 79 KB     | ########## | 100%
#
# fonttools-4.51.0     | 2.0 MB    |            |   0%
# fonttools-4.51.0     | 2.0 MB    |            |   1%
# fonttools-4.51.0     | 2.0 MB    | #6         |  17%
# fonttools-4.51.0     | 2.0 MB    | ###2       |  33%
# fonttools-4.51.0     | 2.0 MB    | ####8      |  49%
# fonttools-4.51.0     | 2.0 MB    | ######4    |  64%
# fonttools-4.51.0     | 2.0 MB    | ########   |  80%
# fonttools-4.51.0     | 2.0 MB    | #########6 |  96%
# fonttools-4.51.0     | 2.0 MB    | ########## | 100%
#
# importlib_resources- | 61 KB     |            |   0%
# importlib_resources- | 61 KB     | ##6        |  26%
# importlib_resources- | 61 KB     | ########## | 100%
# importlib_resources- | 61 KB     | ########## | 100%
#
# qt-main-5.15.2       | 59.4 MB   |            |   0%
# qt-main-5.15.2       | 59.4 MB   |            |   0%
# qt-main-5.15.2       | 59.4 MB   |            |   1%
# qt-main-5.15.2       | 59.4 MB   | 1          |   1%
# qt-main-5.15.2       | 59.4 MB   | 1          |   2%
# qt-main-5.15.2       | 59.4 MB   | 2          |   2%
# qt-main-5.15.2       | 59.4 MB   | 2          |   3%
# qt-main-5.15.2       | 59.4 MB   | 3          |   3%
# qt-main-5.15.2       | 59.4 MB   | 3          |   4%
# qt-main-5.15.2       | 59.4 MB   | 4          |   4%
# qt-main-5.15.2       | 59.4 MB   | 4          |   5%
# qt-main-5.15.2       | 59.4 MB   | 5          |   5%
# qt-main-5.15.2       | 59.4 MB   | 6          |   6%
# qt-main-5.15.2       | 59.4 MB   | 6          |   7%
# qt-main-5.15.2       | 59.4 MB   | 7          |   7%
# qt-main-5.15.2       | 59.4 MB   | 7          |   8%
# qt-main-5.15.2       | 59.4 MB   | 8          |   9%
# qt-main-5.15.2       | 59.4 MB   | 9          |   9%
# qt-main-5.15.2       | 59.4 MB   | #          |  10%
# qt-main-5.15.2       | 59.4 MB   | #          |  11%
# qt-main-5.15.2       | 59.4 MB   | #1         |  12%
# qt-main-5.15.2       | 59.4 MB   | #2         |  13%
# qt-main-5.15.2       | 59.4 MB   | #3         |  14%
# qt-main-5.15.2       | 59.4 MB   | #5         |  15%
# qt-main-5.15.2       | 59.4 MB   | #6         |  16%
# qt-main-5.15.2       | 59.4 MB   | #7         |  17%
# qt-main-5.15.2       | 59.4 MB   | #8         |  19%
# qt-main-5.15.2       | 59.4 MB   | #9         |  20%
# qt-main-5.15.2       | 59.4 MB   | ##1        |  21%
# qt-main-5.15.2       | 59.4 MB   | ##2        |  22%
# qt-main-5.15.2       | 59.4 MB   | ##3        |  24%
# qt-main-5.15.2       | 59.4 MB   | ##4        |  25%
# qt-main-5.15.2       | 59.4 MB   | ##5        |  26%
# qt-main-5.15.2       | 59.4 MB   | ##6        |  27%
# qt-main-5.15.2       | 59.4 MB   | ##7        |  28%
# qt-main-5.15.2       | 59.4 MB   | ###        |  31%
# qt-main-5.15.2       | 59.4 MB   | ###1       |  32%
# qt-main-5.15.2       | 59.4 MB   | ###3       |  33%
# qt-main-5.15.2       | 59.4 MB   | ###4       |  35%
# qt-main-5.15.2       | 59.4 MB   | ###6       |  36%
# qt-main-5.15.2       | 59.4 MB   | ###7       |  37%
# qt-main-5.15.2       | 59.4 MB   | ###8       |  39%
# qt-main-5.15.2       | 59.4 MB   | ###9       |  40%
# qt-main-5.15.2       | 59.4 MB   | ####1      |  41%
# qt-main-5.15.2       | 59.4 MB   | ####2      |  42%
# qt-main-5.15.2       | 59.4 MB   | ####3      |  43%
# qt-main-5.15.2       | 59.4 MB   | ####4      |  45%
# qt-main-5.15.2       | 59.4 MB   | ####5      |  46%
# qt-main-5.15.2       | 59.4 MB   | ####6      |  47%
# qt-main-5.15.2       | 59.4 MB   | ####7      |  48%
# qt-main-5.15.2       | 59.4 MB   | ####8      |  49%
# qt-main-5.15.2       | 59.4 MB   | ####9      |  50%
# qt-main-5.15.2       | 59.4 MB   | #####      |  51%
# qt-main-5.15.2       | 59.4 MB   | #####1     |  52%
# qt-main-5.15.2       | 59.4 MB   | #####2     |  53%
# qt-main-5.15.2       | 59.4 MB   | #####3     |  54%
# qt-main-5.15.2       | 59.4 MB   | #####4     |  55%
# qt-main-5.15.2       | 59.4 MB   | #####6     |  56%
# qt-main-5.15.2       | 59.4 MB   | #####6     |  57%
# qt-main-5.15.2       | 59.4 MB   | #####8     |  58%
# qt-main-5.15.2       | 59.4 MB   | #####9     |  59%
# qt-main-5.15.2       | 59.4 MB   | #####9     |  60%
# qt-main-5.15.2       | 59.4 MB   | ######1    |  61%
# qt-main-5.15.2       | 59.4 MB   | ######2    |  63%
# qt-main-5.15.2       | 59.4 MB   | ######4    |  64%
# qt-main-5.15.2       | 59.4 MB   | ######5    |  65%
# qt-main-5.15.2       | 59.4 MB   | ######6    |  67%
# qt-main-5.15.2       | 59.4 MB   | ######7    |  67%
# qt-main-5.15.2       | 59.4 MB   | ######8    |  68%
# qt-main-5.15.2       | 59.4 MB   | ######9    |  69%
# qt-main-5.15.2       | 59.4 MB   | #######    |  70%
# qt-main-5.15.2       | 59.4 MB   | #######1   |  71%
# qt-main-5.15.2       | 59.4 MB   | #######2   |  72%
# qt-main-5.15.2       | 59.4 MB   | #######3   |  73%
# qt-main-5.15.2       | 59.4 MB   | #######4   |  74%
# qt-main-5.15.2       | 59.4 MB   | #######5   |  75%
# qt-main-5.15.2       | 59.4 MB   | #######6   |  76%
# qt-main-5.15.2       | 59.4 MB   | #######7   |  77%
# qt-main-5.15.2       | 59.4 MB   | #######8   |  79%
# qt-main-5.15.2       | 59.4 MB   | #######9   |  80%
# qt-main-5.15.2       | 59.4 MB   | ########   |  81%
# qt-main-5.15.2       | 59.4 MB   | ########1  |  82%
# qt-main-5.15.2       | 59.4 MB   | ########2  |  83%
# qt-main-5.15.2       | 59.4 MB   | ########3  |  84%
# qt-main-5.15.2       | 59.4 MB   | ########4  |  84%
# qt-main-5.15.2       | 59.4 MB   | ########4  |  85%
# qt-main-5.15.2       | 59.4 MB   | ########5  |  86%
# qt-main-5.15.2       | 59.4 MB   | ########6  |  86%
# qt-main-5.15.2       | 59.4 MB   | ########6  |  87%
# qt-main-5.15.2       | 59.4 MB   | ########7  |  87%
# qt-main-5.15.2       | 59.4 MB   | ########7  |  88%
# qt-main-5.15.2       | 59.4 MB   | ########8  |  88%
# qt-main-5.15.2       | 59.4 MB   | ########8  |  89%
# qt-main-5.15.2       | 59.4 MB   | ########9  |  89%
# qt-main-5.15.2       | 59.4 MB   | ########9  |  90%
# qt-main-5.15.2       | 59.4 MB   | #########  |  90%
# qt-main-5.15.2       | 59.4 MB   | #########  |  91%
# qt-main-5.15.2       | 59.4 MB   | #########1 |  91%
# qt-main-5.15.2       | 59.4 MB   | #########1 |  92%
# qt-main-5.15.2       | 59.4 MB   | #########2 |  92%
# qt-main-5.15.2       | 59.4 MB   | #########2 |  93%
# qt-main-5.15.2       | 59.4 MB   | #########3 |  93%
# qt-main-5.15.2       | 59.4 MB   | #########3 |  94%
# qt-main-5.15.2       | 59.4 MB   | #########4 |  94%
# qt-main-5.15.2       | 59.4 MB   | #########4 |  95%
# qt-main-5.15.2       | 59.4 MB   | #########5 |  95%
# qt-main-5.15.2       | 59.4 MB   | #########5 |  96%
# qt-main-5.15.2       | 59.4 MB   | #########6 |  96%
# qt-main-5.15.2       | 59.4 MB   | #########6 |  97%
# qt-main-5.15.2       | 59.4 MB   | #########7 |  98%
# qt-main-5.15.2       | 59.4 MB   | #########8 |  98%
# qt-main-5.15.2       | 59.4 MB   | #########8 |  99%
# qt-main-5.15.2       | 59.4 MB   | #########9 |  99%
# qt-main-5.15.2       | 59.4 MB   | ########## | 100%
# qt-main-5.15.2       | 59.4 MB   | ########## | 100%
#
# matplotlib-3.7.2     | 9 KB      |            |   0%
# matplotlib-3.7.2     | 9 KB      | ########## | 100%
# matplotlib-3.7.2     | 9 KB      | ########## | 100%
#
# matplotlib-base-3.7. | 6.6 MB    |            |   0%
# matplotlib-base-3.7. | 6.6 MB    |            |   0%
# matplotlib-base-3.7. | 6.6 MB    | 5          |   6%
# matplotlib-base-3.7. | 6.6 MB    | #1         |  12%
# matplotlib-base-3.7. | 6.6 MB    | #6         |  16%
# matplotlib-base-3.7. | 6.6 MB    | ##1        |  21%
# matplotlib-base-3.7. | 6.6 MB    | ###2       |  33%
# matplotlib-base-3.7. | 6.6 MB    | ###9       |  40%
# matplotlib-base-3.7. | 6.6 MB    | ####6      |  46%
# matplotlib-base-3.7. | 6.6 MB    | #####2     |  53%
# matplotlib-base-3.7. | 6.6 MB    | ######4    |  64%
# matplotlib-base-3.7. | 6.6 MB    | #######3   |  73%
# matplotlib-base-3.7. | 6.6 MB    | ########2  |  83%
# matplotlib-base-3.7. | 6.6 MB    | #########2 |  93%
# matplotlib-base-3.7. | 6.6 MB    | ########## | 100%
#
# pyqt-5.15.10         | 4.1 MB    |            |   0%
# pyqt-5.15.10         | 4.1 MB    |            |   0%
# pyqt-5.15.10         | 4.1 MB    | 5          |   6%
# pyqt-5.15.10         | 4.1 MB    | ##9        |  29%
# pyqt-5.15.10         | 4.1 MB    | ####7      |  48%
# pyqt-5.15.10         | 4.1 MB    | ######5    |  66%
# pyqt-5.15.10         | 4.1 MB    | ########2  |  83%
# pyqt-5.15.10         | 4.1 MB    | ########## | 100%
# pyqt-5.15.10         | 4.1 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# ϵͳ�Ҳ���ָ����·����
# ϵͳ�Ҳ���ָ����·����

# %% [markdown]
# 我们通过导入 matplotlib 库，然后查看 matplotlib 库的版本号。

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.7.2
